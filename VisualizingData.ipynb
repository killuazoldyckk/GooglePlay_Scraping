# %%
import pandas as pd

# Load the reviews data
csv_file_path = 'data/reviews/reviews.csv'
reviews_df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
reviews_df.head()
# Out:
#                                reviewId              userName  \
# 0  585fe52f-7e9f-409c-b777-78777918aa72        Mohammad Nasir
# 1  f1cea906-9006-4c69-a630-9e463144e1f6                 Akaza
# 2  3c267a1d-1e2e-4cbe-a8f8-6ec51f2a2de9  Rafid Taufiqul Hakim
# 3  5c588499-a241-414f-ac68-d5a8b67e0721                Kigyuu
# 4  78cdb8fc-1f5a-4368-92ff-d3dc790c55b9         Haikal Mangun
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Gamenya sebenarnya sangat seru, konsepnya mena...      1            295
# 1  Bagus, cuman untuk analognya bisa disetting ag...      4             24
# ...

# %%
# Display all unique game IDs
unique_ids = reviews_df['game_id'].unique()
unique_ids
# Out:
# array(['com.supercell.squad', 'com.miniclip.eightballpool',
#        'com.budgestudios.googleplay.PawPatrolRescueWorld',
#        'com.dts.freefireth',
#        'com.budgestudios.googleplay.BarbieDreamhouse',
#        'com.scopely.whiplash', 'mad.royale.tanks',
#        'com.hotheadgames.google.free.survivors',
#        'com.fgol.HungrySharkEvolution', 'com.lilithgame.hgame.gp',
#        'com.volcanoforce.lost2', 'com.n3twork.tetris',
#        'com.ea.gp.fifamobile', 'com.mobile.legends',
#        'com.igg.android.lordsmobile', 'com.garena.game.bc',
#        'com.netmarble.sololv', 'com.ig.supermarket.manager.simulator',
#        'com.roblox.client', 'com.game.minicraft.village',
#        'com.dts.freefiremax', 'com.PlayMax.playergames',
#        'com.ig.moto.racing', 'jp.garud.ssimulator',
#        'com.build.vip.realm.city', 'com.Earthkwak.Platformer',
#        'io.supercent.pizzaidle', 'com.outfit7.mytalkingtomfriends',
# ...

# %% [markdown]
# Data Preprocessing

# %%
# Drop rows with missing values
reviews_df.dropna(inplace=True)

# %%
columns_to_remove = ['reviewCreatedVersion', 'replyContent', 'repliedAt']  

reviews_df.drop(columns=columns_to_remove, inplace=True)

# %%
reviews_df
# Out:
#                                     reviewId         userName  \
# 2001    354808e6-bb21-43fe-bba5-5cb1cd120140        Van Broto
# 2002    225e078b-2d27-4042-8d1e-4944738bdd23     faldian pasa
# 2003    e0b5d952-1f86-44cf-a8d5-2db9ca9c0da2       Tirta Vivo
# 2004    5d547a69-8a44-47d5-b08b-1dba495ae51f     Febba Satria
# 2005    5907f136-d334-4052-acbe-01a9cb589aca  Heri Hutagalung
# ...                                      ...              ...
# 250161  b66a21fc-e60b-43b7-becf-14e03b807768      Ochie Ochie
# 250167  7ed53e1b-cba7-44ff-8ec3-9bfe093f8724   Elfa Andrianus
# 250275  05636129-ef12-404e-8b49-64e6319cd770      Summer Sign
# 250400  51b5fdbe-8294-43e0-97c3-b11e3e698b84            Akeww
# 250431  ab8487c9-e863-47f7-afe7-eb539448c281         Bari Eek
#
#                                                 userImage  \
# 2001    https://play-lh.googleusercontent.com/a/ACg8oc...
# 2002    https://play-lh.googleusercontent.com/a/ACg8oc...
# ...

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25370 entries, 2001 to 250431
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       25370 non-null  object
#  1   userName       25370 non-null  object
#  2   userImage      25370 non-null  object
#  3   content        25370 non-null  object
#  4   score          25370 non-null  int64
#  5   thumbsUpCount  25370 non-null  int64
#  6   at             25370 non-null  object
#  7   appVersion     25370 non-null  object
#  8   game_id        25370 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 1.9+ MB

# %%
reviews_df.describe()
# Out:
#               score  thumbsUpCount
# count  25370.000000   25370.000000
# mean       3.078952      64.345053
# std        1.682431     492.215783
# min        1.000000       0.000000
# 25%        1.000000       0.000000
# 50%        3.000000       1.000000
# 75%        5.000000       8.000000
# max        5.000000   22465.000000
